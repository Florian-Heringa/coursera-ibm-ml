# %%
rmse_res = {
    "knn":1.2865,
    "nmf":1.3002,
    "nn":0.4429,
    "emb_lin_reg":0.8138,
}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=rmse_res.values(), y=rmse_res.keys(), hue=rmse_res.keys(), legend=None, palette="tab10")
plt.title("RMSE for different recommender architectures")
plt.xlabel("RMSE")
# Out:
# Text(0.5, 0, 'RMSE')
